# %% [markdown]
# <a href="https://colab.research.google.com/github/manikanta-52/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-25 14:54:05--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   188MB/s    in 0.4s
#
# 2023-05-25 14:54:07 (188 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 17576  1712.04313v1  We describe a new challenge aimed at discoveri...    cs
# 37211  1610.09077v2  The research of personalized recommendation te...    cs
# 36525   1405.6043v1  We extend the knowledge about so-called struct...    cs
# 1927   1611.08002v2  A Semantic Compositional Network (SCN) is deve...    cs
# 10510   1205.2622v1  The problem of multilabel classification when ...    cs
# ...             ...                                                ...   ...
# 40675   1309.0238v1  Scikit-learn is an increasingly popular machin...    cs
# 5589    1309.1193v2  Our work is focused on the joint sparsity reco...  stat
# 5569    1303.0561v2  Decision tree learning is a popular approach f...  stat
# 13439   1304.4055v2  The processes occurring in climatic change evo...    cs
# 22022   1311.6359v3  Given data sampled from a number of variables,...  stat
#
#                                                    title  year  \
# 17576            The Zero Resource Speech Challenge 2017  2017
# 37211  Integrating Topic Models and Latent Factors fo...  2016
# 36525  Understanding model counting for $β$-acyclic C...  2014
# 1927   Semantic Compositional Networks for Visual Cap...  2016
# 10510  Using the Gene Ontology Hierarchy when Predict...  2012
# ...                                                  ...   ...
# 40675  API design for machine learning software: expe...  2013
# 5589   Confidence-constrained joint sparsity recovery...  2013
# 5569   Top-down particle filtering for Bayesian decis...  2013
# 13439  Multiobjective optimization in Gene Expression...  2013
# 22022  Score-based Causal Learning in Additive Noise ...  2013
#
#                                                 keywords
# 17576  [challenge, discovering, challenge, challenge,...
# 37211  [personalized, recommendation, techniques, mai...
# 36525  [knowledge, structural, restrictions, mathrmsa...
# 1927   [compositional, developed, captioning, probabi...
# 10510  [multilabel, classification, hierarchical, cat...
# ...                                                  ...
# 40675  [increasingly, efficient, accessible, applicat...
# 5589   [corrupted, formulate, confidence, constrained...
# 5569   [classification, regression, statistics, formu...
# 13439  [processes, occurring, evolution, variations, ...
# 22022  [variables, interested, underlying, relationsh...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 17576    [challenge, discovering, challenge, challenge,...
# 37211    [personalized, recommendation, techniques, mai...
# 36525    [knowledge, structural, restrictions, mathrmsa...
# 1927     [compositional, developed, captioning, probabi...
# 10510    [multilabel, classification, hierarchical, cat...
#                                ...
# 18373    [formulates, necessary, sufficient, condition,...
# 15582    [segmentation, boundaries, important, processi...
# 22931    [meaningful, transformations, thickness, handw...
# 21540    [existence, calibrated, forecasters, arbitrary...
# 39320    [sequential, identification, sequential, imple...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8817 words.
# Out of those 4588 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="04141ccb-88e3-4ed1-9c54-e404a4d411c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("04141ccb-88e3-4ed1-9c54-e404a4d411c8")) {                    Plotly.newPlot(                        "04141ccb-88e3-4ed1-9c54-e404a4d411c8",                        [{"x":["discovering","challenge","presented","discussed","generalize","evaluation","languages","constructing","understanding","extremely","mathematically","coordinate","literature","factorization","directions","correlated","integrating","numerical","mathematical","information","respectively","approaches","performance","techniques","appealing","correspondingly","experimental","mainstream","objective","collectively","procedures","theoretical","objectives","optimizing","recommendation","difficult","prediction","optimization","scenarios","reasonable","personalized","practically","functions","intuitively","restaurant","unfortunately","randomization","fortunately","deviation","algorithms","constraint","programming","coincidence","satisfaction","polynomial","structural","algorithm","restrictions","knowledge","elimination","parameters","benchmark","developed","dependent","composition","quantitatively","compositional","corresponding","qualitatively","outperforms","significantly","captioning","probability","supervised","equations","incorporating","naturally","application","efficiently","hierarchical","independent","automatically","controlled","predicting","independently","categorization","reconciliation","vocabularies","classification","multilabel","annotation","hierarchy","computational","efficiency","robustness","especially","numerically","principal","influential","geometric","components","detection","dimensional","including","introduce","applicable","efficient","convergence","extracting","structure","dirichlet","fundamental","nonparametric","shrinkage","hyperparameters","constructions","suggested","generalization","confirmed","constrained","partition","expectation","overlapping","appropriate","furthermore","intensity","collapsed","experimentally","empirically","generative","appropriately","indicated","typically","marginalized","asymptotic","generating","independence","statistical","consistent","estimating","assumptions","stationary","coefficients","estimator","collection","combination","inferences","reactions","potential","similarity","particular","understand","conditions","representation","translation","monitoring","infectious","recognise","baselines","representations","technique","communities","classifiers","execution","therefore","effective","classified","providing","excessive","maliciously","architecture","engineered","explanation","technically","important","demonstrates","characters","databases","localizes","relevance","additional","cheminformatics","identified","interpretable","developing","principles","demonstrate","contemporary","outperforming","properties","established","universal","engineering","optimized","interpretability","solvation","performances","implemented","represent","interactions"],"y":[23,172,153,62,54,266,118,42,179,45,13,28,146,33,49,24,41,76,73,701,81,442,871,356,17,4,374,7,170,9,40,179,33,49,32,161,231,294,76,35,25,14,224,17,2,38,4,2,10,595,89,115,2,19,56,64,818,15,349,7,233,210,193,73,33,21,24,155,23,273,244,18,171,215,21,57,53,240,164,98,139,189,49,82,30,19,4,5,505,2,65,35,280,166,96,109,12,39,14,73,112,360,157,272,303,48,411,95,60,325,23,87,15,4,6,13,24,115,6,57,34,32,25,81,178,28,2,51,75,118,12,7,105,2,20,123,28,155,84,68,66,26,38,23,85,154,13,3,154,159,277,76,133,372,111,33,5,4,63,232,240,16,120,23,147,223,30,93,5,2,223,10,26,2,389,47,32,53,3,31,122,0,43,43,65,37,551,10,30,216,58,38,56,46,22,0,31,103,114,69],"type":"bar"},{"x":["discovering","challenge","presented"," ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4588,), (4588, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7975

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Overcoming</span> <span style=''>Problems</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Measurement</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Biological</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Complexity</span> <br/><br/><span style=''>In</span> <span style=''>a</span> <span style=''>genetic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fluctuations</span> <span style=''>of</span> <span style=''>the</span> <span style=''>entropy</span> <span style=''>of</span> <span style=''>a</span> <span style=''>genome</span> <span style=''>over</span> <span style=''>time</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpreted</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>fluctuations</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3276515151515152);'>information</span> <span style=''>that</span> <span style=''>the</span> <span style=''>genomes</span> <span style=''>organism</span> <span style=''>is</span> <span style=''>storing</span> <span style=''>about</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.5918367346938775);'>environment</span> <span style=''>being</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.6000000000000001);'>reflected</span> <span style=''>in</span> <span style=''>more</span> <span style=''>complex</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>organisms</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computation</span> <span style=''>of</span> <span style=''>this</span> <span style=''>entropy</span> <span style=''>presents</span> <span style='background-color:rgba(0, 255, 0, 0.4242424242424243);'>technical</span> <span style=''>problems</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>small</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>sizes</span> <span style=''>used</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>and</span> <span style=''>test</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>way</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measuring</span> <span style=''>the</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>population</span> <span style=''>by</span> <span style=''>means</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithmic</span> <span style='background-color:rgba(0, 255, 0, 0.3276515151515152);'>information</span> <span style=''>theory</span> <span style=''>where</span> <span style=''>the</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>between</span> <span style=''>two</span> <span style=''>generational</span> <span style=''>steps</span> <span style=''>is</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Kolmogorov</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>complexity</span> <span style=''>of</span> <span style=''>the</span> <span style=''>first</span> <span style=''>step</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditioned</span> <span style=''>to</sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Amortized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Autoencoders</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Amortized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>(AVI)</span> <span style=''>replaces</span> <span style=''>instance</span> <span style=''>specific</span> <span style=''>local</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>with</span> <span style=''>a</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>network</span> <span style=''>While</span> <span style=''>AVI</span> <span style=''>has</span> <span style=''>enabled</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>training</span> <span style=''>of</span> <span style=''>deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>(VAE)</span> <span style=''>recent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>work</span> <span style=''>suggests</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>networks</span> <span style=''>can</span> <span style=''>produce</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suboptimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>hybrid</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>use</span> <span style=''>AVI</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>initialize</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>and</span> <span style=''>run</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>(SVI)</span> <span style=''>to</span> <span style=''>refine</span> <span style=''>them</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Crucially</span> <span style=''>the</span> <span style=''>local</span> <span style=''>SVI</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>is</span> <span style=''>itself</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differentiable</span> <span style=''>so</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>network</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>can</span> <span style=''>be</span> <span style=''>trained</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>with</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>This</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>amortized</span> <span style=''>approach</span> <span style=''>enables</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Copula</span> <span style=''>based</span> <span style=''>Kernel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Dependency</span> <span style=''>Measures</span> <br/><br/><span style=''>The</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>new</span> <span style=''>copula</span> <span style=''>based</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measuring</span> <span style='background-color:rgba(255, 0, 0, 0.37209302325581384);'>dependence</span> <span style=''>between</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3853904282115869);'>variables</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>extends</span> <span style=''>the</span> <span style=''>Maximum</span> <span style=''>Mean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Discrepancy</span> <span style=''>to</span> <span style=''>the</span> <span style=''>copula</span> <span style=''>of</span> <span style=''>the</span> <span style=''>joint</span> <span style='background-color:rgba(255, 0, 0, 0.3275261324041811);'>distribution</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>has</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>advantageous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Similarly</span> <span style=''>to</span> <span style=''>Shannon</span> <span style=''>mutual</span> <span style='background-color:rgba(0, 255, 0, 0.3276515151515152);'>information</span> <span style=''>the</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.37209302325581384);'>dependence</span> <span style=''>measure</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>invariant</span> <span style=''>to</span> <span style=''>any</span> <span style=''>strictly</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>transformation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3853904282115869);'>variables</span> <span style=''>This</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>for</span> <span style=''>example</span> <span style=''>in</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.735632183908046);'>estimator</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistent</span> <span style=''>robust</span> <span style=''>to</span> <span style=''>outliers</span> <span style=''>and</span> <span style=''>uses</span> <span style=''>rank</span> <span style='background-color:rgba(255, 0, 0, 0.30136986301369856);'>statistics</span> <span style=''>only</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.4328358208955223);'>convergence</span> <span style=''>rate</span> <span style=''>and</span> <span style=''>propose</span> <span style='background-color:rgba(255, 0, 0, 0.34883720930232553);'>independence</span> <span style=''>tests</span> <span style=''>too</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>illustrate</span> <span style=''>the</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Convolutional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Autoencoder</span> <span style=''>for</span> <span style=''>Multi</span> <span style=''>Subject</span> <span style=''>fMRI</span> <span style=''>Data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Aggregation</span> <br/><br/><span style=''>Finding</span> <span style=''>the</span> <span style=''>most</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>effective</span> <span style=''>way</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregate</span> <span style=''>multi</span> <span style=''>subject</span> <span style=''>fMRI</span> <span style=''>data</span> <span style=''>is</span> <span style=''>a</span> <span style=''>long</span> <span style=''>standing</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>problem</span> <span style=''>It</span> <span style=''>is</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increasing</span> <span style=''>interest</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contemporary</span> <span style=''>fMRI</span> <span style=''>studies</span> <span style=''>of</span> <span style=''>human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>cognition</span> <span style=''>due</span> <span style=''>to</span> <span style=''>the</span> <span style=''>scarcity</span> <span style=''>of</span> <span style=''>data</span> <span style=''>per</span> <span style=''>subject</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>variability</span> <span style=''>of</span> <span style=''>brain</span> <span style=''>anatomy</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>functional</span> <span style=''>response</span> <span style=''>across</span> <span style=''>subjects</span> <span style=''>Recent</span> <span style=''>work</span> <span style=''>on</span> <span style=''>latent</span> <span style=''>factor</span> <span style=''>models</span> <span style=''>shows</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>promising</span> <span style=''>results</span> <span style=''>in</span> <span style=''>this</span> <span style=''>task</span> <span style=''>but</span> <span style=''>this</span> <span style=''>approach</span> <span style=''>does</span> <span style=''>not</span> <span style=''>preserve</span> <span style=''>spatial</span> <span style=''>locality</span> <span style=''>in</span> <span style=''>the</span> <span style=''>brain</span> <span style=''>We</span> <span style=''>examine</span> <span style=''>two</span> <span style=''>ways</span> <span style=''>to</span> <span style=''>combine</span> <span style=''>the</span> <span style=''>ideas</span> <span style=''>of</span> <span style=''>a</span> <span style=''>factor</span> <span style=''>model</span> <span style=''>and</span> <span style=''>a</span> <span style=''>searchlight</span> <span style=''>based</span> <span style=''>analysis</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>aggregate</span> <span style=''>multi</span> <span style=''>subject</span> <span style=''>fMRI</span> <span style=''>data</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preserving</span> <span style=''>spatial</span> <span style=''>locality</span> <span style=''>We</span> <span style=''>first</span> <span style=''>do</span> <span style=''>this</span> <span style=''>directly</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combining</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>factor</span> <span style=''>method</span> <span style=''>known</span> <span style=''>as</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08004307250538406)
# 	segmentation (0.0681981335247667)
# 	experimental (0.1342426417803302)
# 	knowledge (0.1252692031586504)
# 	representation (0.13352476669059585)
# 	detection (0.12921751615218952)
# 	different (0.25305096913137115)
# 	information (0.25161521895190236)
# 	recognition (0.12419239052404882)
# 	convolutional (0.12957645369705673)
#
# Some Statistics words are:
# 	stochastic (0.13902681231380337)
# 	theoretical (0.15690168818272096)
# 	variables (0.1365441906653426)
# 	statistical (0.15441906653426019)
# 	estimation (0.1817279046673287)
# 	algorithm (0.40218470705064546)
# 	inference (0.19910625620655412)
# 	distribution (0.18917576961271101)
# 	dimensional (0.1861966236345581)
# 	regression (0.17428003972194636)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="87b9467b-f029-4b19-abd3-911394a4f038" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87b9467b-f029-4b19-abd3-911394a4f038")) {                    Plotly.newPlot(                        "87b9467b-f029-4b19-abd3-911394a4f038",                        [{"x":["discovering","challenge","presented","discussed","generalize","evaluation","languages","constructing","understanding","extremely","mathematically","coordinate","literature","factorization","directions","correlated","integrating","numerical","mathematical","information","respectively","approaches","performance","techniques","appealing","correspondingly","experimental","mainstream","objective","collectively","procedures","theoretical","objectives","optimizing","recommendation","difficult","prediction","optimization","scenarios","reasonable","personalized","practically","functions","intuitively","restaurant","unfortunately","randomization","fortunately","deviation","algorithms","constraint","programming","coincidence","satisfaction","polynomial","structural","algorithm","restrictions","knowledge","elimination","parameters","benchmark","developed","dependent","composition","quantitatively","compositional","corresponding","qualitatively","outperforms","significantly","captioning","probability","supervised","equations","incorporating","naturally","application","efficiently","hierarchical","independent","automatically","controlled","predicting","independently","categorization","reconciliation","vocabularies","classification","multilabel","annotation","hierarchy","computational","efficiency","robustness","especially","numerically","principal","influential","geometric","components","detection","dimensional","including","introduce","applicable","efficient","convergence","extracting","structure","dirichlet","fundamental","nonparametric","shrinkage","hyperparameters","constructions","suggested","generalization","confirmed","constrained","partition","expectation","overlapping","appropriate","furthermore","intensity","collapsed","experimentally","empirically","generative","appropriately","indicated","typically","marginalized","asymptotic","generating","independence","statistical","consistent","estimating","assumptions","stationary","coefficients","estimator","collection","combination","inferences","reactions","potential","similarity","particular","understand","conditions","representation","translation","monitoring","infectious","recognise","baselines","representations","technique","communities","classifiers","execution","therefore","effective","classified","providing","excessive","maliciously","architecture","engineered","explanation","technically","important","demonstrates","characters","databases","localizes","relevance","additional","cheminformatics","identified","interpretable","developing","principles","demonstrate","contemporary","outperforming","properties","established","universal","engineering","optimized","interpretability","solvation","performances","implemented","represent","interactions","interface","extracted","interaction","gathering","dimensionality","widespread","projections","projected","proposing","frequently","alternative","minimizes","successful","straightforward","extensive","competitive","predictive","component","projection","significant","experiments","statistically","difference","distribution","reduction","regression","heuristic","logarithm","synthetic","impossible","locations","partitioned","simulations","reasonably","boundaries","deficient","recovering","applications","proportional","selection","complexity","theoretic","consistently","subjective","comparison","different","assessing","automatic","evaluates","consuming","decompositions","observations","stochastic","absolu ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	cheminformatics
# 	solvation
# 	competitiveness
# 	underdamped
# 	counterexample
# 	econometrics
# 	martingales
# 	semiparametric
# 	unconfounded
# 	emphmulti
# 	recidivism
# 	tibshirani
# 	ancestral
# 	refitting
# 	checkable
# 	maximizer
# 	straggler
# 	stragglers
# 	nonsmooth
# 	binarycategorical
# Some words which never appear in Statistics papers:
# 	reconciliation
# 	reactions
# 	recognise
# 	maliciously
# 	annotates
# 	tinyimagenet
# 	disjunctive
# 	rewritability
# 	accomplishment
# 	enumerable
# 	intersecting
# 	repetitive
# 	effortless
# 	unaffordable
# 	fraudster
# 	satisficing
# 	commitment
# 	recompute
# 	requesting
# 	incentives

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.081854043392505e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7433333333333333
